# %%
prompt = input("Enter prompt: ")
# Out:
# Enter prompt: car

# %%
import requests
from PIL import Image

API_URL = "https://api-inference.huggingface.co/models/cloudqi/cqi_text_to_image_pt_v0"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content

image_bytes = query({
    "inputs": prompt,
})

# Access the image with PIL.Image
image = Image.open(io.BytesIO(image_bytes))
image.show()  # Display the image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F7AD010FE20>

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/prompthero/openjourney-v4"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": prompt,
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))

image.show()  # Display the image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7F7AC0229900>
