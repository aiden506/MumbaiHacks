# %%
# prompt = input("Enter prompt: ")
# prompt = "single tyre blank background"
# prompt = "single tyre no background"
# prompt = "lamp no background"
prompt = "chair no background"

# %%
import requests
from PIL import Image
import io

API_URL = "https://api-inference.huggingface.co/models/cloudqi/cqi_text_to_image_pt_v0"
headers = {"Authorization": "Bearer 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"}

def query(payload):
    response = requests.post(API_URL, headers=headers, json=payload)
    return response.content

image_bytes = query({
    "inputs": prompt,
})
try:
  # Access the image with PIL.Image
  image = Image.open(io.BytesIO(image_bytes))
  image.show()  # Display the image
except UnidentifiedImageError:
  print("An error occured, please try again.")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FC33C2237F0>

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/prompthero/openjourney-v4"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.content
image_bytes = query({
	"inputs": prompt,
})
# You can access the image with PIL.Image for example
import io
from PIL import Image
image = Image.open(io.BytesIO(image_bytes))

image.show()  # Display the image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x512 at 0x7FC31AD69AB0>
